# %%
import pandas as pd
import csv

# %% [markdown]
# # Converting location files

# %% [markdown]
# ## Spain

# %%
header_list = ["postcodes", "poblacionid", "town", "latitude", "longitude", "provinciaid", "region"]

# %%
df = pd.read_csv("../../../../Downloads/postal.cat.csv", sep=";", names=header_list, header=0)

# %%
df.head()
# Out:
#    postcodes  poblacionid              town  latitude  longitude  provinciaid  \
# 0        240            1  Alegría-Dulantzi -2.712437  42.939812            1
# 1        240            1         Abengibre -1.543845  39.210008            1
# 2        240            1         l'Atzúbia -0.151730  38.847430            1
# 3        240            1              Abla -2.779540  37.141210            1
# 4        240            1           Adanero -4.603775  40.944236            1
#
#         region
# 0  Araba/Álava
# 1  Araba/Álava
# 2  Araba/Álava
# 3  Araba/Álava
# 4  Araba/Álava

# %%
df_final = df[["postcodes", "town", "latitude", "longitude", "region"]]

# %%
df_final['uk_region']=None
df_final['uk_region_code']=None
# Out:
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_final['country_iso_alpha2']='ES'
df_final['country_iso_alpha3']='ESP'
df_final['country_iso_numeric']='724'

# %%
list(df_final.columns)
# Out:
# ['postcodes',
#  'town',
#  'latitude',
#  'longitude',
#  'region',
#  'uk_region',
#  'uk_region_code',
#  'country_iso_alpha2',
#  'country_iso_alpha3',
#  'country_iso_numeric']

# %%
df_final.to_csv('location_files/spain.csv',  index = False)

# %%
df2 = pd.read_csv('location_files/spain.csv', sep=",")

# %%
df2.head()
# Out:
#    postcodes              town  latitude  longitude       region  uk_region  \
# 0        240  Alegría-Dulantzi -2.712437  42.939812  Araba/Álava        NaN
# 1        240         Abengibre -1.543845  39.210008  Araba/Álava        NaN
# 2        240         l'Atzúbia -0.151730  38.847430  Araba/Álava        NaN
# 3        240              Abla -2.779540  37.141210  Araba/Álava        NaN
# 4        240           Adanero -4.603775  40.944236  Araba/Álava        NaN
#
#    uk_region_code country_iso_alpha2 country_iso_alpha3  country_iso_numeric
# 0             NaN                 ES                ESP                  724
# 1             NaN                 ES                ESP                  724
# 2             NaN                 ES                ESP                  724
# 3             NaN                 ES                ESP                  724
# 4             NaN                 ES                ESP                  724

# %% [markdown]
# ## UK

# %%
header_list = ['postcodes',
 'eastings',
 'northings',
 'latitude',
 'longitude',
 'town',
 'region',
 'uk_region',
 'uk_region_code',
 'country_string']

# %%
df_uk = pd.read_csv("../../../../Downloads/postcodes_UK.csv", sep=",",names=header_list,header=0)

# %%
df_uk.head()
# Out:
#   postcodes  eastings  northings  latitude  longitude         town  \
# 0      AB10    392900     804900  57.13514   -2.11731     Aberdeen
# 1      AB11    394500     805300  57.13875   -2.09089     Aberdeen
# 2      AB12    393300     801100  57.10100   -2.11060     Aberdeen
# 3      AB13    385600     801900  57.10801   -2.23776   Milltimber
# 4      AB14    383600     801100  57.10076   -2.27073  Peterculter
#
#           region uk_region uk_region_code country_string
# 0  Aberdeen City  Scotland            SCT       Scotland
# 1  Aberdeen City  Scotland            SCT       Scotland
# 2  Aberdeen City  Scotland            SCT       Scotland
# 3  Aberdeen City  Scotland            SCT       Scotland
# 4  Aberdeen City  Scotland            SCT       Scotland

# %%
df_uk['country_iso_alpha2']='GB'
df_uk['country_iso_alpha3']='GBR'
df_uk['country_iso_numeric']='826'

# %%
df_uk_final = df_uk[["postcodes", "town", "latitude", "longitude", "region", "country_iso_alpha3", "uk_region", "uk_region_code","country_iso_alpha2", "country_iso_numeric"]]

# %%
df_uk_final.head()
# Out:
#   postcodes         town  latitude  longitude         region  \
# 0      AB10     Aberdeen  57.13514   -2.11731  Aberdeen City
# 1      AB11     Aberdeen  57.13875   -2.09089  Aberdeen City
# 2      AB12     Aberdeen  57.10100   -2.11060  Aberdeen City
# 3      AB13   Milltimber  57.10801   -2.23776  Aberdeen City
# 4      AB14  Peterculter  57.10076   -2.27073  Aberdeen City
#
#   country_iso_alpha3 uk_region uk_region_code country_iso_alpha2  \
# 0                GBR  Scotland            SCT                 GB
# 1                GBR  Scotland            SCT                 GB
# 2                GBR  Scotland            SCT                 GB
# 3                GBR  Scotland            SCT                 GB
# 4                GBR  Scotland            SCT                 GB
#
#   country_iso_numeric
# 0                 826
# 1                 826
# 2                 826
# 3                 826
# 4                 826

# %%
df_uk_final.to_csv('location_files/uk.csv',  index = False)

# %%
df3 = pd.read_csv('location_files/uk.csv', sep=",")

# %%
df3.head()
# Out:
#   postcodes         town  latitude  longitude         region  \
# 0      AB10     Aberdeen  57.13514   -2.11731  Aberdeen City
# 1      AB11     Aberdeen  57.13875   -2.09089  Aberdeen City
# 2      AB12     Aberdeen  57.10100   -2.11060  Aberdeen City
# 3      AB13   Milltimber  57.10801   -2.23776  Aberdeen City
# 4      AB14  Peterculter  57.10076   -2.27073  Aberdeen City
#
#   country_iso_alpha3 uk_region uk_region_code country_iso_alpha2  \
# 0                GBR  Scotland            SCT                 GB
# 1                GBR  Scotland            SCT                 GB
# 2                GBR  Scotland            SCT                 GB
# 3                GBR  Scotland            SCT                 GB
# 4                GBR  Scotland            SCT                 GB
#
#    country_iso_numeric
# 0                  826
# 1                  826
# 2                  826
# 3                  826
# 4                  826

# %% [markdown]
# ## Swiss

# %%
header_list = ['postcodes',
 'post_district',
 'comment',
 'country',
 'region',
 'town',
 'latitude',
 'longitude']

# %%
df_ch = pd.read_csv("../../../../Downloads/post-codes-swiss.csv", sep=",",names=header_list,header=0)

# %%
df_ch.head()
# Out:
#    postcodes              post_district      comment country region      town  \
# 0       1000                   Lausanne          NaN      CH     VD  Lausanne
# 1       1001           Lausanne 1 cases  PO box only      CH     VD  Lausanne
# 2       1002                   Lausanne  PO box only      CH     VD  Lausanne
# 3       1003  Lausanne Secteur de dist.          NaN      CH     VD  Lausanne
# 4       1004                   Lausanne          NaN      CH     VD  Lausanne
#
#     latitude  longitude
# 0  46.567488   6.680964
# 1  46.243526   7.382073
# 2  46.521820   6.632665
# 3  46.520793   6.631489
# 4  46.530039   6.617949

# %%
df_ch['uk_region']=None
df_ch['uk_region_code']=None

# %%
df_ch['country_iso_alpha2']='CH'
df_ch['country_iso_alpha3']='CHE'
df_ch['country_iso_numeric']='756'

# %%
df_ch_final = df_ch[["postcodes", "town", "latitude", "longitude", "region", "country_iso_alpha2","country_iso_alpha3","country_iso_numeric", "uk_region"]]

# %%
df_ch_final.to_csv('location_files/ch.csv',  index = False)

# %%
df4 = pd.read_csv('location_files/ch.csv', sep=",")

# %%
df4.head()
# Out:
#    postcodes      town   latitude  longitude region country_iso_alpha2  \
# 0       1000  Lausanne  46.567488   6.680964     VD                 CH
# 1       1001  Lausanne  46.243526   7.382073     VD                 CH
# 2       1002  Lausanne  46.521820   6.632665     VD                 CH
# 3       1003  Lausanne  46.520793   6.631489     VD                 CH
# 4       1004  Lausanne  46.530039   6.617949     VD                 CH
#
#   country_iso_alpha3  country_iso_numeric  uk_region
# 0                CHE                  756        NaN
# 1                CHE                  756        NaN
# 2                CHE                  756        NaN
# 3                CHE                  756        NaN
# 4                CHE                  756        NaN

# %% [markdown]
# ## Austria

# %%
header_list = ['country_code',
 'postcodes',
 'town',
'region',
'state_code'  ,
               'province',
               'province_code',
               'community',
               'community_code',
               'latitude',
               'longitude'
              ]

# %%
df_at = pd.read_csv("../../../../Downloads/zipcodes.at.csv", sep=",",names=header_list,header=0)

# %%
df_at.head()
# Out:
#   country_code  postcodes                            town      region  \
# 0           AT       7000                      Eisenstadt  Burgenland
# 1           AT       7000  Sankt Georgen am Leithagebirge  Burgenland
# 2           AT       7000      Kleinhöflein im Burgenland  Burgenland
# 3           AT       7071                            Rust  Burgenland
# 4           AT       2443                         Loretto  Burgenland
#
#    state_code             province  province_code   community  community_code  \
# 0           1     Eisenstadt Stadt            101  Eisenstadt           10101
# 1           1     Eisenstadt Stadt            101  Eisenstadt           10101
# 2           1     Eisenstadt Stadt            101  Eisenstadt           10101
# 3           1           Rust Stadt            102        Rust           10201
# 4           1  Eisenstadt-Umgebung            103     Loretto           10320
#
#    latitude  longitude
# 0   47.8457    16.5233
# 1   47.8500    16.5500
# 2   47.8415    16.5041
# 3   47.8012    16.6716
# 4   47.9156    16.5179

# %%
df_at_final = df_at[['postcodes',
 'town',
'region',
               'latitude',
               'longitude'
              ]]

# %%
df_at_final['uk_region']=None
df_at_final['uk_region_code']=None
# Out:
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_at_final['country_iso_alpha2']='AT'
df_at_final['country_iso_alpha3']='AUT'
df_at_final['country_iso_numeric']='040'
# Out:
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_at_final.to_csv('location_files/at.csv',  index = False)

# %%
df7 = pd.read_csv('location_files/at.csv', sep=",")

# %%
df7.head()
# Out:
#    postcodes                            town      region  latitude  longitude  \
# 0       7000                      Eisenstadt  Burgenland   47.8457    16.5233
# 1       7000  Sankt Georgen am Leithagebirge  Burgenland   47.8500    16.5500
# 2       7000      Kleinhöflein im Burgenland  Burgenland   47.8415    16.5041
# 3       7071                            Rust  Burgenland   47.8012    16.6716
# 4       2443                         Loretto  Burgenland   47.9156    16.5179
#
#    uk_region  uk_region_code country_iso_alpha2 country_iso_alpha3  \
# 0        NaN             NaN                 AT                AUT
# 1        NaN             NaN                 AT                AUT
# 2        NaN             NaN                 AT                AUT
# 3        NaN             NaN                 AT                AUT
# 4        NaN             NaN                 AT                AUT
#
#    country_iso_numeric
# 0                   40
# 1                   40
# 2                   40
# 3                   40
# 4                   40

# %% [markdown]
# ## Germany

# %%
header_list = ['country_code',
 'postcodes',
 'town',
'region',
'state_code'  ,
               'province',
               'province_code',
               'community',
               'community_code',
               'latitude',
               'longitude'
              ]

# %%
df_de = pd.read_csv("../../../../Downloads/zipcodes.de.csv", sep=",",names=header_list,header=0, dtype=type_dict)

# %%
df_de.head()
# Out:
#   country_code  postcodes         town       region state_code province  \
# 0           DE       1945    Grünewald  Brandenburg         BB      NaN
# 1           DE       1945     Lindenau  Brandenburg         BB      NaN
# 2           DE       1945   Hohenbocka  Brandenburg         BB      NaN
# 3           DE       1945  Schwarzbach  Brandenburg         BB      NaN
# 4           DE       1945     Guteborn  Brandenburg         BB      NaN
#
#    province_code                        community  community_code  latitude  \
# 0              0  Landkreis Oberspreewald-Lausitz           12066   51.4000
# 1              0  Landkreis Oberspreewald-Lausitz           12066   51.4000
# 2              0  Landkreis Oberspreewald-Lausitz           12066   51.4310
# 3              0  Landkreis Oberspreewald-Lausitz           12066   51.4500
# 4              0  Landkreis Oberspreewald-Lausitz           12066   51.4167
#
#    longitude
# 0    14.0000
# 1    13.7333
# 2    14.0098
# 3    13.9333
# 4    13.9333

# %%
df_de_final = df_at[['postcodes',
 'town',
'region',
               'latitude',
               'longitude'
              ]]

# %%
df_de_final['uk_region']=None
df_de_final['uk_region_code']=None
# Out:
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_de_final['country_iso_alpha2']='DE'
df_de_final['country_iso_alpha3']='DEU'
df_de_final['country_iso_numeric']='276'
# Out:
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/simonjuliangreiner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ddf_de_finalf_de.head()
# Out:
#   country_code  postcodes         town       region state_code province  \
# 0           DE       1945    Grünewald  Brandenburg         BB      NaN
# 1           DE       1945     Lindenau  Brandenburg         BB      NaN
# 2           DE       1945   Hohenbocka  Brandenburg         BB      NaN
# 3           DE       1945  Schwarzbach  Brandenburg         BB      NaN
# 4           DE       1945     Guteborn  Brandenburg         BB      NaN
#
#    province_code                        community  community_code  latitude  \
# 0              0  Landkreis Oberspreewald-Lausitz           12066   51.4000
# 1              0  Landkreis Oberspreewald-Lausitz           12066   51.4000
# 2              0  Landkreis Oberspreewald-Lausitz           12066   51.4310
# 3              0  Landkreis Oberspreewald-Lausitz           12066   51.4500
# 4              0  Landkreis Oberspreewald-Lausitz           12066   51.4167
#
#    longitude
# 0    14.0000
# 1    13.7333
# 2    14.0098
# 3    13.9333
# 4    13.9333

# %%
df_de_final = df_de[["postcodes", "town", "latitude", "longitude", "region", "country_iso_alpha2","country_iso_alpha3","country_iso_numeric", "uk_region"]]

# %%
df_de_final.to_csv('location_files/de.csv',  index = False)
